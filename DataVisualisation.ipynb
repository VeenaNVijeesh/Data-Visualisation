# %%
#import sufficient libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read the dataset
df=pd.read_csv('C:/Users/HP/Downloads/data.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.shape
# Out:
# (32, 5)

# %%
df.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
#checking for missing values
df.isnull().sum()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   32.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   63.839129
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  300.000000
# 75%     60.000000  106.500000  132.250000  341.325000
# max    450.000000  130.000000  175.000000  479.000000

# %%
#impute values into the missing values
missing_dates = df['Date'].isnull()
df.loc[missing_dates, 'Date'] = df['Date'].ffill()
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#impute values into the missing values
df['Calories'] = df['Calories'].fillna(df['Calories'].mean())
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df["Pulse"].unique()
# Out:
# array([110, 117, 103, 109, 102, 104,  98, 100, 106,  90,  97, 108, 130,
#        105,  92], dtype=int64)

# %%
df["Maxpulse"].unique()
# Out:
# array([130, 145, 135, 175, 148, 127, 136, 134, 133, 124, 147, 120, 128,
#        132, 123, 112, 125, 131, 119, 101, 126, 118, 129, 115], dtype=int64)

# %%
df["Calories"].unique()
# Out:
# array([409.1 , 479.  , 340.  , 282.4 , 406.  , 300.  , 374.  , 253.3 ,
#        195.1 , 269.  , 329.3 , 250.7 , 345.3 , 379.3 , 275.  , 215.2 ,
#        304.68, 323.  , 243.  , 364.2 , 282.  , 246.  , 334.5 , 250.  ,
#        241.  , 280.  , 380.3 ])

# %%
df.value_counts('Duration')
# Out:
# Duration
# 60     24
# 45      6
# 30      1
# 450     1
# dtype: int64

# %%
df.value_counts('Pulse')
# Out:
# Pulse
# 100    6
# 103    4
# 98     3
# 102    3
# 92     2
# 104    2
# 109    2
# 110    2
# 117    2
# 90     1
# 97     1
# 105    1
# 106    1
# 108    1
# 130    1
# dtype: int64

# %%
df.value_counts('Maxpulse')
# Out:
# Maxpulse
# 120    5
# 132    4
# 123    2
# 101    1
# 130    1
# 148    1
# 147    1
# 145    1
# 136    1
# 135    1
# 134    1
# 133    1
# 131    1
# 129    1
# 112    1
# 128    1
# 127    1
# 126    1
# 125    1
# 124    1
# 119    1
# 118    1
# 115    1
# 175    1
# dtype: int64

# %%
df.value_counts('Calories')
# Out:
# Calories
# 300.00    3
# 243.00    2
# 250.70    2
# 304.68    2
# 323.00    1
# 409.10    1
# 406.00    1
# 380.30    1
# 379.30    1
# 374.00    1
# 364.20    1
# 345.30    1
# 340.00    1
# 334.50    1
# 329.30    1
# 195.10    1
# 215.20    1
# 282.40    1
# 282.00    1
# 280.00    1
# 275.00    1
# 269.00    1
# 253.30    1
# 250.00    1
# 246.00    1
# 241.00    1
# 479.00    1
# dtype: int64

# %%
plt.subplot(2,2,1)
plt.hist(df['Pulse'])

plt.subplot(2,2,2)
plt.hist(df['Maxpulse'])

plt.subplot(2,2,3)
plt.hist(df['Calories'])

plt.show()

# %%
#outlier detection
plt.subplot(2,2,1)
plt.boxplot(df['Duration'])

plt.subplot(2,2,2)
plt.boxplot(df['Pulse'])

plt.subplot(2,2,3)
plt.boxplot(df['Maxpulse'])

plt.subplot(2,2,4)
plt.boxplot(df['Calories'])
plt.show()

# %%
#if there is any duplicated values
df[df.duplicated()]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 12        60  '2020/12/12'    100       120     250.7

# %%
#correlations 
plt.scatter(x='Pulse',y='Calories',data=df)
